# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_table('data_clean/ppo_attn_ult.txt', 
                   sep=';', 
                   header=None,
                   names=['time', 'utilization'])

df = df[:-2]

df1 = pd.read_table('data_clean/ppo_ult.txt', 
                   sep=';', 
                   header=None,
                   names=['time', 'utilization'])

df1 = df1[:-2]

df2 = pd.read_table('data_clean/a2c_ult.txt', 
                   sep=';', 
                   header=None,
                   names=['time', 'utilization'])

df2 = df2[:-2]

df3 = pd.read_table('data_clean/ppo_kit_ult.txt', 
                   sep=';', 
                   header=None,
                   names=['time', 'utilization'])

# %%
df1 = df1[df1['utilization'] > 0.1]
df1
# Out:
#         time  utilization
# 1        806     0.293578
# 2       1612     0.352294
# 3       2418     0.440367
# 4       2671     0.352294
# 5       3224     0.381651
# ...      ...          ...
# 1993  814408     0.851376
# 1994  817256     0.587156
# 1995  818008     0.469725
# 1996  825020     0.381651
# 1997  827164     0.322936
#
# [1984 rows x 2 columns]

# %%
df3 = df3[df3['utilization'] > 0.2]
df3
# Out:
#          time  utilization
# 15     125537     0.457418
# 45     130419     0.202096
# 46     130419     0.206254
# 47     130419     0.210413
# 48     130419     0.214571
# ...       ...          ...
# 1990  1260106     0.363606
# 1991  1260367     0.359448
# 1992  1282910     0.317864
# 1993  1284343     0.276281
# 1994  1292088     0.233699
#
# [1814 rows x 2 columns]

# %%
df3['utilization'][:1500].mean()
# Out:
# 0.7846755655355955

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   time        2000 non-null   int64
#  1   utlization  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB

# %%
df3['utilization'][:1500].plot()
# Out:
# <Axes: >

# %%
df['utlization'].plot()
# Out:
# <Axes: >

# %%
df1['utlization'].plot()
# Out:
# <Axes: >

# %%
df['utlization'].mean()
# Out:
# 0.6486323479442746

# %%
df1['utilization'].mean()
# Out:
# 0.6524976185631844

# %%
df2['utlization'].mean()
# Out:
# 0.6486857270114151

# %%
df2['utlization'].plot()
# Out:
# <Axes: >

# %%
df_rwd = pd.read_table('data_clean/ppo_attn_rwd.txt', 
                   sep=';', 
                   header=None,
                   names=['reward'])

df1_rwd = pd.read_table('data_clean/ppo_rwd.txt', 
                   sep=';', 
                   header=None,
                   names=['reward'])

df2_rwd = pd.read_table('data_clean/a2c_rwd.txt', 
                   sep=';', 
                   header=None,
                   names=['reward'])

# %%
df_rwd.mean()
# Out:
# reward    0.254605
# dtype: float64

# %%
df_rwd.plot()
# Out:
# <Axes: >

# %%
df1_rwd.mean()
# Out:
# reward    0.253965
# dtype: float64

# %%
df1_rwd.plot()
# Out:
# <Axes: >

# %%
df2_rwd.mean()
# Out:
# reward    0.255207
# dtype: float64

# %%
df2_rwd.plot()
# Out:
# <Axes: >
